# %% [markdown]
# ### Importing Libraries

# %%
#to access datasets
import pandas as pd
import numpy as np


#for encoding 
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ### Accessing Data

# %%
#accessing the user profile dataset
user_profile = pd.read_csv('cleanedDatasets/cleaned_user_profile.csv')
user_profile.head()
# Out:
#    userid degree_1      degree_1_specializations  \
# 0    1001     B.E.  Computer Science Engineering
# 1    1002     B.E.  Computer Science Engineering
# 2    1003     B.E.  Computer Science Engineering
# 3    1004     B.E.  Computer Science Engineering
# 4    1005     B.E.  Computer Science Engineering
#
#                                  known_languages  \
# 0              ['English', ' Marathi', ' Hindi']
# 1                              ['Hindi English']
# 2                                    ['Unknown']
# 3  ['English', ' Hindi', ' Marathi', ' Marwari']
# 4   ['English', 'Hindi  ', 'Kashmiri ', ' Urdu']
#
#                                           key_skills  \
# 0  ['C', ' Java', ' Keras', ' Flask', ' Deep Lear...
# 1  ['Java', ' Neural Networks', ' AI', ' Python',...
# 2                                        ['Unknown']
# 3  ['XML', ' C', ' Java', ' Data Structures', ' P...
# 4  ['XML', ' Word', ' Data Structures', ' Communi...
#
#                                     career_objective  \
# 0  Computer Engineering student with good technic...
# 1  Interested in working under company offering A...
# 2                                            Unknown
# 3  Currently a final year student of Computer Eng...
# 4  To have a growth oriented and challenging care...
#
#                                       key_skills_str
# 0  C,  Java,  Keras,  Flask,  Deep Learning,  Sel...
# 1  Java,  Neural Networks,  AI,  Python,  Html5, ...
# 2                                            Unknown
# 3  XML,  C,  Java,  Data Structures,  Python,  Mo...
# 4  XML,  Word,  Data Structures,  Communication, ...

# %%
#accessing the courses dataset
courses = pd.read_csv('cleanedDatasets/cleaned_course_dataset.csv')
courses.head()
# Out:
#     sr_ degree_1 degree_1_specializations  campus key_skills key_skills_str
# 0  1001    B.E.                Mechanical  MITCOE  ['CATIA']          CATIA
# 1  1002    B.E.                Mechanical  MITCOE  ['CATIA']          CATIA
# 2  1003    B.E.                Mechanical  MITAOE  ['CATIA']          CATIA
# 3  1004    B.E.                Mechanical  MITCOE  ['CATIA']          CATIA
# 4  1005    B.E.                Mechanical  MITCOE  ['CATIA']          CATIA

# %%
#accessing the user rating dataset
user_rating = pd.read_csv('cleanedDatasets/cleaned_user_ratings.csv')
user_rating.head()
# Out:
#    course_id  user_id  rating
# 0       2001     1001       5
# 1       2001     1002       3
# 2       2001     1003       1
# 3       2001     1004       0
# 4       2001     1005       2

# %% [markdown]
# ### Encoding Data Filtering

# %% [markdown]
# Purpose: Content-based recommender systems focus on item attributes and content. They recommend items similar to those a user has liked in the past based on shared features.

# %% [markdown]
# #### Encoding the data as neccessary

# %% [markdown]
# Why Encode Categorical Variables?
# - Categorical variables (like degree, specialization, and known languages) need to be encoded because most machine learning algorithms work with numerical data.
# - Encoding converts categorical attributes into numerical representations, allowing algorithms to process them effectively.

# %% [markdown]
# ##### User Profile

# %%
#encoding the user profile dataset using label encoding for degree_1
le = LabelEncoder()
user_profile['degree_1'] = le.fit_transform(user_profile['degree_1'])
user_profile.head()
# Out:
#    userid  degree_1      degree_1_specializations  \
# 0    1001         0  Computer Science Engineering
# 1    1002         0  Computer Science Engineering
# 2    1003         0  Computer Science Engineering
# 3    1004         0  Computer Science Engineering
# 4    1005         0  Computer Science Engineering
#
#                                  known_languages  \
# 0              ['English', ' Marathi', ' Hindi']
# 1                              ['Hindi English']
# 2                                    ['Unknown']
# 3  ['English', ' Hindi', ' Marathi', ' Marwari']
# 4   ['English', 'Hindi  ', 'Kashmiri ', ' Urdu']
#
#                                           key_skills  \
# 0  ['C', ' Java', ' Keras', ' Flask', ' Deep Lear...
# 1  ['Java', ' Neural Networks', ' AI', ' Python',...
# 2                                        ['Unknown']
# 3  ['XML', ' C', ' Java', ' Data Structures', ' P...
# 4  ['XML', ' Word', ' Data Structures', ' Communi...
#
#                                     career_objective  \
# 0  Computer Engineering student with good technic...
# 1  Interested in working under company offering A...
# 2                                            Unknown
# 3  Currently a final year student of Computer Eng...
# 4  To have a growth oriented and challenging care...
#
#                                       key_skills_str
# 0  C,  Java,  Keras,  Flask,  Deep Learning,  Sel...
# 1  Java,  Neural Networks,  AI,  Python,  Html5, ...
# 2                                            Unknown
# 3  XML,  C,  Java,  Data Structures,  Python,  Mo...
# 4  XML,  Word,  Data Structures,  Communication, ...

# %%
#encoding the user profile dataset using one-hot encoding for degree_1_specializations 
user_profile = pd.get_dummies(user_profile, columns=['degree_1_specializations'])
user_profile.head()
# Out:
#    userid  degree_1                                known_languages  \
# 0    1001         0              ['English', ' Marathi', ' Hindi']
# 1    1002         0                              ['Hindi English']
# 2    1003         0                                    ['Unknown']
# 3    1004         0  ['English', ' Hindi', ' Marathi', ' Marwari']
# 4    1005         0   ['English', 'Hindi  ', 'Kashmiri ', ' Urdu']
#
#                                           key_skills  \
# 0  ['C', ' Java', ' Keras', ' Flask', ' Deep Lear...
# 1  ['Java', ' Neural Networks', ' AI', ' Python',...
# 2                                        ['Unknown']
# 3  ['XML', ' C', ' Java', ' Data Structures', ' P...
# 4  ['XML', ' Word', ' Data Structures', ' Communi...
#
#                                     career_objective  \
# 0  Computer Engineering student with good technic...
# 1  Interested in working under company offering A...
# 2                                            Unknown
# 3  Currently a final year student of Computer Eng...
# 4  To have a growth oriented and challenging care...
#
#                                       key_skills_str  \
# 0  C,  Java,  Keras,  Flask,  Deep Learning,  Sel...
# 1  Java,  Neural Networks,  AI,  Python,  Html5, ...
# 2                                            Unknown
# 3  XML,  C,  Java,  Data Structures,  Python,  Mo...
# 4  XML,  Word,  Data Structures,  Communication, ...
#
#    degree_1_specializations_Computer Science Engineering  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
#    degree_1_specializations_Electronics  Telecommunication Engineering  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    degree_1_specializations_Mechanical
# 0                                False
# 1                                False
# 2                                False
# 3                                False
# 4                                False

# %%
#encoding the user profile dataset using one-hot encoding for known_languages
user_profile = pd.get_dummies(user_profile, columns=['known_languages'])
user_profile.head()
# Out:
#    userid  degree_1                                         key_skills  \
# 0    1001         0  ['C', ' Java', ' Keras', ' Flask', ' Deep Lear...
# 1    1002         0  ['Java', ' Neural Networks', ' AI', ' Python',...
# 2    1003         0                                        ['Unknown']
# 3    1004         0  ['XML', ' C', ' Java', ' Data Structures', ' P...
# 4    1005         0  ['XML', ' Word', ' Data Structures', ' Communi...
#
#                                     career_objective  \
# 0  Computer Engineering student with good technic...
# 1  Interested in working under company offering A...
# 2                                            Unknown
# 3  Currently a final year student of Computer Eng...
# 4  To have a growth oriented and challenging care...
#
#                                       key_skills_str  \
# 0  C,  Java,  Keras,  Flask,  Deep Learning,  Sel...
# 1  Java,  Neural Networks,  AI,  Python,  Html5, ...
# 2                                            Unknown
# 3  XML,  C,  Java,  Data Structures,  Python,  Mo...
# 4  XML,  Word,  Data Structures,  Communication, ...
#
#    degree_1_specializations_Computer Science Engineering  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
#    degree_1_specializations_Electronics  Telecommunication Engineering  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    degree_1_specializations_Mechanical  \
# 0                                False
# 1                                False
# 2                                False
# 3                                False
# 4                                False
#
#    known_languages_[' Android-Studio; Blockchain']  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
#
#    known_languages_[' Android; Php']  ...  \
# 0                              False  ...
# 1                              False  ...
# 2                              False  ...
# 3                              False  ...
# 4                              False  ...
#
#    known_languages_['enthusiasm-motivation; motivation; Technical-and-problem-solving; communication; commitment; patience; interpersonal; maths; problem-solving; chemistry; physics']  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    known_languages_['hindi', 'marathi', 'english languages']  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    known_languages_['java', 'CPP']  \
# 0                            False
# 1                            False
# 2                            False
# 3                            False
# 4                            False
#
#    known_languages_['java', 'image processing']  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#    known_languages_['java; NodeJS; HTML;  MS-SQL']  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
#
#    known_languages_['java; NodeJS; jav; HTML; MS-SQL']  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    known_languages_['mysql; Javascript']  known_languages_['no']  \
# 0                                  False                   False
# 1                                  False                   False
# 2                                  False                   False
# 3                                  False                   False
# 4                                  False                   False
#
#    known_languages_['python', 'C']  known_languages_['python', 'Html']
# 0                            False                               False
# 1                            False                               False
# 2                            False                               False
# 3                            False                               False
# 4                            False                               False
#
# [5 rows x 264 columns]

# %% [markdown]
# ##### Course Datset

# %%
#encoding the course dataset using  label encoding for degree_1
courses['degree_1'] = le.fit_transform(courses['degree_1'])
courses.head()
# Out:
#     sr_  degree_1 degree_1_specializations  campus key_skills key_skills_str
# 0  1001         0               Mechanical  MITCOE  ['CATIA']          CATIA
# 1  1002         0               Mechanical  MITCOE  ['CATIA']          CATIA
# 2  1003         0               Mechanical  MITAOE  ['CATIA']          CATIA
# 3  1004         0               Mechanical  MITCOE  ['CATIA']          CATIA
# 4  1005         0               Mechanical  MITCOE  ['CATIA']          CATIA

# %%
#encoding the course dataset using one-hot encoding for degree_1_specializations
courses = pd.get_dummies(courses, columns=['degree_1_specializations'])
courses.head()
# Out:
#     sr_  degree_1  campus key_skills key_skills_str  \
# 0  1001         0  MITCOE  ['CATIA']          CATIA
# 1  1002         0  MITCOE  ['CATIA']          CATIA
# 2  1003         0  MITAOE  ['CATIA']          CATIA
# 3  1004         0  MITCOE  ['CATIA']          CATIA
# 4  1005         0  MITCOE  ['CATIA']          CATIA
#
#    degree_1_specializations_Civil Engineering  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
#
#    degree_1_specializations_Computer Science Engineering  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    degree_1_specializations_Electronics  Telecommunication Engineering  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    degree_1_specializations_Mechanical
# 0                                 True
# 1                                 True
# 2                                 True
# 3                                 True
# 4                                 True

# %%
#encoding the course dataset using  label encoding for campus
courses['campus'] = le.fit_transform(courses['campus'])
courses.head()
# Out:
#     sr_  degree_1  campus key_skills key_skills_str  \
# 0  1001         0       3  ['CATIA']          CATIA
# 1  1002         0       3  ['CATIA']          CATIA
# 2  1003         0       2  ['CATIA']          CATIA
# 3  1004         0       3  ['CATIA']          CATIA
# 4  1005         0       3  ['CATIA']          CATIA
#
#    degree_1_specializations_Civil Engineering  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
#
#    degree_1_specializations_Computer Science Engineering  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    degree_1_specializations_Electronics  Telecommunication Engineering  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    degree_1_specializations_Mechanical
# 0                                 True
# 1                                 True
# 2                                 True
# 3                                 True
# 4                                 True

# %% [markdown]
# ### Saving the datasets

# %%
courses.to_csv('cleanedDatasets/cleaned_encoded_course_dataset.csv', index=False)
user_profile.to_csv('cleanedDatasets/cleaned_encoded_user_profile_dataset.csv', index=False)
